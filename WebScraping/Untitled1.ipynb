# %%
NYT_URL = 'http://api.nytimes.com/svc/search/v2/articlesearch.json?sort=newest&fq=section_name:"Technology"&api-key=4ab21f2ea4bb6a0893135fbf0881689d:15:69947362'

# %%
from bs4 import BeautifulSoup
import requests
import json
import time
from dateutil import parser
from pymongo import MongoClient
from pymongo import errors

# %%
def init_mongo():
    # SETUP MONGO DB CONNECTION VIA PYMONGO
    client = MongoClient()

    # CREATE DATABASE NAMED NYT
    db = client.nyt_tech

    # CREATE A COLLECTION IN NYT NAMED ARTICLES (SHORTCUT TO OT NAMED COLLECTION)
    collection = db.articles
    return db, collection

# %%
# payload  = {'sort': 'newest',
#             'fq':'news_desk:("")',
#             'begin_date': '20140901',
#             'end_date':   '20140902',
#             'api-key': API_KEY, 
#             'page': 0}

api = requests.get(NYT_URL)#, params=payload)
print dir(api)
print api.url
api.ok
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__doc__', '__format__', '__getattribute__', '__getstate__', '__hash__', '__init__', '__iter__', '__module__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
# http://api.nytimes.com/svc/search/v2/articlesearch.json?sort=newest&fq=section_name:%22Technology%22&api-key=4ab21f2ea4bb6a0893135fbf0881689d:15:69947362
# True

# %%
#api.json()
l = api.json()['response']['docs']
for item in l:
    print item['pub_date'], item['section_name'], item['web_url']
# Out:
# 2014-11-03T17:21:02Z Technology http://www.nytimes.com/reuters/2014/11/03/technology/03reuters-intel-wearables.html
# 2014-11-03T16:46:05Z Technology http://www.nytimes.com/reuters/2014/11/03/technology/03reuters-britain-security-gchq.html
# 2014-11-03T15:54:06Z Technology http://bits.blogs.nytimes.com/2014/11/03/southwest-airlines-offers-free-streaming-of-apples-beats-music-service/
# 2014-11-03T15:01:03Z Technology http://www.nytimes.com/reuters/2014/11/03/technology/03reuters-usa-florida-carnival.html
# 2014-11-03T14:07:42Z Technology http://www.nytimes.com/reuters/2014/11/03/technology/03reuters-wireless-volte.html
# 2014-11-03T13:48:21Z Technology http://www.nytimes.com/reuters/2014/11/03/technology/03reuters-healthcare-tech-ella.html
# 2014-11-03T13:18:10Z Technology http://www.nytimes.com/aponline/2014/11/03/technology/ap-us-tec-digital-life-review-android-tablets.html
# ...

# %%
api.json()
# Out:
# {u'copyright': u'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#  u'response': {u'docs': [{u'_id': u'5458000938f0d8086c45db70',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'organization': u'REUTERS',
#      u'original': u'By REUTERS',
#      u'person': []},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Wrist-Worn Drone Wins Intel Smart Clothing Contest',
#      u'print_headline': u'Wrist-Worn Drone Wins Intel Smart Clothing Contest'},
#     u'keywords': [],
#     u'lead_paragraph': u'Intel Corp on Monday awarded $500,000 to a group of do-it-yourselfers who developed a wristband that converts to a camera-equipped drone to win a contest the chipmaker hopes will help guarantee it a leading position in the emerging market for wearable computing devices.',
#     u'multimedia': [],
#     u'news_desk': u'None',
#     u'print_page': None,
#     u'pub_date': u'2014-11-03T17:21:02Z',
#     u'section_name': u'Technology',
# ...

# %%
api.json()['response']['docs'][0]
# Out:
# {u'_id': u'5458000938f0d8086c45db70',
#  u'abstract': None,
#  u'blog': [],
#  u'byline': {u'organization': u'REUTERS',
#   u'original': u'By REUTERS',
#   u'person': []},
#  u'document_type': u'article',
#  u'headline': {u'main': u'Wrist-Worn Drone Wins Intel Smart Clothing Contest',
#   u'print_headline': u'Wrist-Worn Drone Wins Intel Smart Clothing Contest'},
#  u'keywords': [],
#  u'lead_paragraph': u'Intel Corp on Monday awarded $500,000 to a group of do-it-yourselfers who developed a wristband that converts to a camera-equipped drone to win a contest the chipmaker hopes will help guarantee it a leading position in the emerging market for wearable computing devices.',
#  u'multimedia': [],
#  u'news_desk': u'None',
#  u'print_page': None,
#  u'pub_date': u'2014-11-03T17:21:02Z',
#  u'section_name': u'Technology',
# ...
